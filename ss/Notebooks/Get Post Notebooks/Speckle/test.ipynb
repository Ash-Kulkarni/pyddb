# %%
from specklepy.api import operations
from specklepy.api.client import SpeckleClient
from specklepy.api.credentials import get_default_account
from specklepy.transports.server import ServerTransport

HOST = "v2.speckle.arup.com"
STREAM_ID = "4e45b1513d"
COMMIT_ID = "d702025ce2"

# create and authenticate a client
client = SpeckleClient(host=HOST)
account = get_default_account()
client.authenticate(token=account.token)

# get the specified commit data
commit = client.commit.get(STREAM_ID, COMMIT_ID)

# create an authenticated server transport from the client and receive the commit obj
transport = ServerTransport(client=client, stream_id=STREAM_ID)
res = operations.receive(commit.referencedObject, transport)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ASH~1.KUL\AppData\Local\Temp/ipykernel_26772/638959559.py in <module>
#      18 # create an authenticated server transport from the client and receive the commit obj
#      19 transport = ServerTransport(client=client, stream_id=STREAM_ID)
# ---> 20 res = operations.receive(commit.referencedObject, transport)
#      21
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\api\operations.py in receive(obj_id, remote_transport, local_transport)
#      68     obj_string = local_transport.get_object(obj_id)
#      69     if obj_string:
# ---> 70         return serializer.read_json(obj_string=obj_string)
#      71
#      72     if not remote_transport:
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in read_json(self, obj_string)
#     240             return None
#     241         obj = ujson.loads(obj_string)
# --> 242         return self.recompose_base(obj=obj)
#     243
#     244     def recompose_base(self, obj: dict) -> Base:
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in recompose_base(self, obj)
#     298             # 3. handle all other cases (base objects, lists, and dicts)
#     299             else:
# --> 300                 base.__setattr__(prop, self.handle_value(value))
#     301
#     302         return base
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in handle_value(self, obj)
#     319         # lists (regular and chunked)
#     320         if isinstance(obj, list):
# --> 321             obj_list = [self.handle_value(o) for o in obj]
#     322             if (
#     323                 hasattr(obj_list[0], "speckle_type")
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in <listcomp>(.0)
#     319         # lists (regular and chunked)
#     320         if isinstance(obj, list):
# --> 321             obj_list = [self.handle_value(o) for o in obj]
#     322             if (
#     323                 hasattr(obj_list[0], "speckle_type")
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in handle_value(self, obj)
#     333         # bases
#     334         if isinstance(obj, dict) and "speckle_type" in obj:
# --> 335             return self.recompose_base(obj=obj)
#     336
#     337         # dictionaries
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in recompose_base(self, obj)
#     298             # 3. handle all other cases (base objects, lists, and dicts)
#     299             else:
# --> 300                 base.__setattr__(prop, self.handle_value(value))
#     301
#     302         return base
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in handle_value(self, obj)
#     333         # bases
#     334         if isinstance(obj, dict) and "speckle_type" in obj:
# --> 335             return self.recompose_base(obj=obj)
#     336
#     337         # dictionaries
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in recompose_base(self, obj)
#     298             # 3. handle all other cases (base objects, lists, and dicts)
#     299             else:
# --> 300                 base.__setattr__(prop, self.handle_value(value))
#     301
#     302         return base
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in handle_value(self, obj)
#     333         # bases
#     334         if isinstance(obj, dict) and "speckle_type" in obj:
# --> 335             return self.recompose_base(obj=obj)
#     336
#     337         # dictionaries
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in recompose_base(self, obj)
#     298             # 3. handle all other cases (base objects, lists, and dicts)
#     299             else:
# --> 300                 base.__setattr__(prop, self.handle_value(value))
#     301
#     302         return base
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in handle_value(self, obj)
#     333         # bases
#     334         if isinstance(obj, dict) and "speckle_type" in obj:
# --> 335             return self.recompose_base(obj=obj)
#     336
#     337         # dictionaries
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\serialization\base_object_serializer.py in recompose_base(self, obj)
#     282             # 1. handle primitives (ints, floats, strings, and bools) or None
#     283             if isinstance(value, PRIMITIVES) or value is None:
# --> 284                 base.__setattr__(prop, value)
#     285                 continue
#     286
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\objects\base.py in __setattr__(self, name, value)
#     206         if isinstance(attr, property):
#     207             try:
# --> 208                 attr.__set__(self, value)
#     209             except AttributeError:
#     210                 pass  # the prop probably doesn't have a setter
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\objects\base.py in units(self, value)
#     311     @units.setter
#     312     def units(self, value: str):
# --> 313         self._units = get_units_from_string(value)
#     314
#     315     def get_member_names(self) -> List[str]:
#
# ~\Documents\_dtd_venv\JupyterTable\lib\site-packages\specklepy\objects\units.py in get_units_from_string(unit)
#      29
#      30 def get_units_from_string(unit: str):
# ---> 31     unit = str.lower(unit)
#      32     for name, alternates in UNITS_STRINGS.items():
#      33         if unit in alternates:
#
# TypeError: descriptor 'lower' for 'str' objects doesn't apply to a 'NoneType' object

# %%
spaces = res["@Spaces"]


#  "07f4051a-753e-4815-ad88-e9660269d012"  LTHW Flow Rate
#  '0bbba30d-cd88-406e-8a72-bedc6466907d' Space reference id
#  '2b83d1f6-771f-4b95-b423-7608d6748b79' Space_Mechanical_Heating_Type_Terminal
#  '44c45290-c51f-4211-a5c0-9dee24d3e91d' Space_Lighting_Control_Dimming_Type'
#  '51908f9d-e4a7-4454-978b-a17cc3135e03' CHW Flow Temperature
#  '669f5573-fe80-48ed-af4c-cd194c43a34b' Water Specific Heat Capacity
#  '7f3d6cfd-b816-48cd-80ee-50e462dbfda0' Space_Mechanical_Cooling_Type_Terminal
#  '95afcd22-7def-4ca7-a4ad-f24d8c31e3ac' LTHW Return Temperature
#  'a0f5d781-af71-4a81-9740-a8cf5a115c72' LTHW Flow Temperature
#  'c8b3b0a1-06b5-425c-8fa7-cc803cca5d43' Space_Type
#  'd4c66fc1-a9a7-40db-9883-bbc51708415e' Water Density
#  'e9d9f461-46d5-4f89-8efb-bcbf9fd430f6' CHW Flow Rate
#  'eb9600ba-f3b3-4ebd-a3c2-5b656b445a94' CHW Return Temperature
