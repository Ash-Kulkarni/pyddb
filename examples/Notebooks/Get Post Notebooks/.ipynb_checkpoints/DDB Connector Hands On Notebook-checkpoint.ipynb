# %% [markdown]
# ### Imports & Authentication

# %%
import sys
sys.path.append('../../Scripts')

import ddb_get_post as pyddb
from ddb_get_post import Project, Source, Asset
from ddb_jupyter import *
# Out:
# Using default account: Ash.Kulkarni@arup.com

# %% [markdown]
# ### Select DDB Environment & Project

# %%
pyddb.site = "sandbox" # "dev" or "prod"
job_number = "07869171"
project_id = pyddb.add_new_project(job_number)
project_id
# Out:
# Project already exists.  Project ID retreived.
# '6cfd4db8-aa3c-ec11-8140-005056b57459'

# %% [markdown]
# ### Get Products
# Gets all asset instances that are on the specified project and are of the 'product' type.
#
# Returns list of asset ids.

# %%
product_type_id = "49202b68-1ff9-489b-a8ff-9e7d890f1bf4" # asset type id of product

products = pyddb.get_assets(project_id = project_id, asset_type_id = product_type_id)
product_ids = [x["id"] for x in products]
product_ids
# Out:
# ['72bec7cb-7937-c497-13f4-65f1e7b9b4a4',
#  'b4bec7cb-7f52-e2b1-3b38-74a9308d1026']

# %% [markdown]
# Gets all parameter instances on the products.

# %%
product_parameters = pyddb.get_parameters(asset_id = product_ids)
product_parameters
# Out:
# [{'id': '72aa3668-d5a1-4ca5-9cfc-41ad1560328b',
#   'created_at': '2021-12-06T11:52:58.441Z',
#   'parameter_type': {'id': 'fdb85750-6c8a-4033-94e4-d91d5825e788',
#    'name': 'Volume',
#    'data_type': 'number',
#    'unit_type_id': 'b5ab1238-eef6-4996-8e18-ad4171f522ff',
#    'created_at': '2021-11-03T20:45:56.196Z',
#    'updated_at': '2022-02-03T13:10:59.716Z',
#    'global_parameter': True,
#    'deleted_at': None},
#   'parents': [{'id': 'b4bec7cb-7f52-e2b1-3b38-74a9308d1026',
#     'name': 'Septic tank',
#     'project_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'children': [],
#     'parent': '10bec7cb-77a0-67f3-4887-987442fb68e0',
#     'asset_type': {'id': '49202b68-1ff9-489b-a8ff-9e7d890f1bf4',
#      'parent_id': 'e4b51a06-4f87-4108-9fac-fe44182621fb',
#      'name': 'product',
#      'created_at': '2021-11-03T20:45:55.945Z',
#      'updated_at': '2021-11-03T20:45:55.945Z',
#      'asset_sub_type': False,
#      'deleted_at': None,
#      'asset_type_group': None}}],
#   'revision': {'id': 'd1a58ea3-c17f-40f3-a86f-fc50f7be8f91',
#    'status': 'answered',
#    'source': {'id': '7e7c80f6-9d35-46fa-9846-17123cd201fb',
#     'created_at': '2022-01-26T15:10:40.875Z',
#     'updated_at': '2022-01-26T15:10:40.875Z',
#     'deleted_at': None,
#     'time': None,
#     'date_day': None,
#     'date_month': None,
#     'date_year': None,
#     'reference': 'Jupyter Notebook',
#     'reference_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'reference_table': 'projects',
#     'reference_url': 'https://ddb.arup.com/project',
#     'scope': None,
#     'title': 'Automation Lab Upload Tool',
#     'url': None,
#     'source_type': {'id': '3169ba8f-d474-4ee3-8891-09817a03b196',
#      'name': 'Auto',
#      'visible': False,
#      'deleted_at': None}},
#    'comment': None,
#    'location_in_source': None,
#    'values': [{'id': '3ebf4b78-5f16-b952-c7b9-d3d25134495d',
#      'value': 10,
#      'unit': {'id': '2ae7438a-4b8c-4f66-be4f-01315dc0cb8d',
#       'name': 'm³',
#       'unit_type_id': 'b5ab1238-eef6-4996-8e18-ad4171f522ff',
#       'unit_system_id': '50115948-140f-48fc-b5f2-c56e96869734',
#       'created_at': '2021-11-03T20:45:56.805Z',
#       'updated_at': '2021-11-03T20:45:56.805Z',
#       'deleted_at': None}}],
#    'created_at': '2022-01-26T15:11:06.788Z',
#    'created_by': {'staff_id': 75806,
#     'staff_name': 'Ash Kulkarni',
#     'email': 'Ash.Kulkarni@arup.com',
#     'company_centre_arup_unit': '01-509 Buildings North',
#     'location_name': 'Glasgow Office',
#     'grade_level': 2,
#     'my_people_page_url': 'https://arup-my.sharepoint.com/PersonImmersive.aspx?accountname=i:0%23.f%7cmembership%7cAsh.Kulkarni@arup.com'}},
#   'deleted_at': None},
#  {'id': '949874a7-bcc2-46c0-9676-b453c1c0af10',
#   'created_at': '2021-12-06T11:52:55.202Z',
#   'parameter_type': {'id': 'fdb85750-6c8a-4033-94e4-d91d5825e788',
#    'name': 'Volume',
#    'data_type': 'number',
#    'unit_type_id': 'b5ab1238-eef6-4996-8e18-ad4171f522ff',
#    'created_at': '2021-11-03T20:45:56.196Z',
#    'updated_at': '2022-02-03T13:10:59.716Z',
#    'global_parameter': True,
#    'deleted_at': None},
#   'parents': [{'id': '72bec7cb-7937-c497-13f4-65f1e7b9b4a4',
#     'name': 'Rainwater collection tank',
#     'project_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'children': [],
#     'parent': '10bec7cb-77a0-67f3-4887-987442fb68e0',
#     'asset_type': {'id': '49202b68-1ff9-489b-a8ff-9e7d890f1bf4',
#      'parent_id': 'e4b51a06-4f87-4108-9fac-fe44182621fb',
#      'name': 'product',
#      'created_at': '2021-11-03T20:45:55.945Z',
#      'updated_at': '2021-11-03T20:45:55.945Z',
#      'asset_sub_type': False,
#      'deleted_at': None,
#      'asset_type_group': None}}],
#   'revision': {'id': 'abb4580b-46f3-472f-a8fa-26accb427d4e',
#    'status': 'answered',
#    'source': {'id': '7e7c80f6-9d35-46fa-9846-17123cd201fb',
#     'created_at': '2022-01-26T15:10:40.875Z',
#     'updated_at': '2022-01-26T15:10:40.875Z',
#     'deleted_at': None,
#     'time': None,
#     'date_day': None,
#     'date_month': None,
#     'date_year': None,
#     'reference': 'Jupyter Notebook',
#     'reference_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'reference_table': 'projects',
#     'reference_url': 'https://ddb.arup.com/project',
#     'scope': None,
#     'title': 'Automation Lab Upload Tool',
#     'url': None,
#     'source_type': {'id': '3169ba8f-d474-4ee3-8891-09817a03b196',
#      'name': 'Auto',
#      'visible': False,
#      'deleted_at': None}},
#    'comment': None,
#    'location_in_source': None,
#    'values': [{'id': '6abf4b78-44a3-3fdf-8c09-edbfb2f30fca',
#      'value': 11,
#      'unit': {'id': '2ae7438a-4b8c-4f66-be4f-01315dc0cb8d',
#       'name': 'm³',
#       'unit_type_id': 'b5ab1238-eef6-4996-8e18-ad4171f522ff',
#       'unit_system_id': '50115948-140f-48fc-b5f2-c56e96869734',
#       'created_at': '2021-11-03T20:45:56.805Z',
#       'updated_at': '2021-11-03T20:45:56.805Z',
#       'deleted_at': None}}],
#    'created_at': '2022-01-26T15:10:53.244Z',
#    'created_by': {'staff_id': 75806,
#     'staff_name': 'Ash Kulkarni',
#     'email': 'Ash.Kulkarni@arup.com',
#     'company_centre_arup_unit': '01-509 Buildings North',
#     'location_name': 'Glasgow Office',
#     'grade_level': 2,
#     'my_people_page_url': 'https://arup-my.sharepoint.com/PersonImmersive.aspx?accountname=i:0%23.f%7cmembership%7cAsh.Kulkarni@arup.com'}},
#   'deleted_at': None},
#  {'id': 'e08ca0db-cbce-48b2-85b6-d39f273ed3db',
#   'created_at': '2021-12-06T11:52:55.202Z',
#   'parameter_type': {'id': '6cbf4335-35f7-4a17-b214-d6c3aaa53685',
#    'name': 'Embodied carbon for stage A4 transport',
#    'data_type': 'number',
#    'unit_type_id': '4de8c2f9-3fe7-421e-8bb3-ea88527b432c',
#    'created_at': '2021-11-03T20:45:56.196Z',
#    'updated_at': '2022-02-03T12:40:18.781Z',
#    'global_parameter': True,
#    'deleted_at': None},
#   'parents': [{'id': '72bec7cb-7937-c497-13f4-65f1e7b9b4a4',
#     'name': 'Rainwater collection tank',
#     'project_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'children': [],
#     'parent': '10bec7cb-77a0-67f3-4887-987442fb68e0',
#     'asset_type': {'id': '49202b68-1ff9-489b-a8ff-9e7d890f1bf4',
#      'parent_id': 'e4b51a06-4f87-4108-9fac-fe44182621fb',
#      'name': 'product',
#      'created_at': '2021-11-03T20:45:55.945Z',
#      'updated_at': '2021-11-03T20:45:55.945Z',
#      'asset_sub_type': False,
#      'deleted_at': None,
#      'asset_type_group': None}}],
#   'revision': {'id': '67ef67bb-5d06-443a-9787-7512eb48e6a7',
#    'status': 'answered',
#    'source': {'id': 'e3e5a6f7-4a3f-46e8-8c50-aa06f5c9d11b',
#     'created_at': '2022-02-11T11:09:20.193Z',
#     'updated_at': '2022-02-11T11:09:20.193Z',
#     'deleted_at': None,
#     'time': None,
#     'date_day': None,
#     'date_month': None,
#     'date_year': None,
#     'reference': 'Jupyter',
#     'reference_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'reference_table': 'projects',
#     'reference_url': 'https://ddb.arup.com/project',
#     'scope': None,
#     'title': 'A4 Calc Notebook',
#     'url': None,
#     'source_type': {'id': '3169ba8f-d474-4ee3-8891-09817a03b196',
#      'name': 'Auto',
#      'visible': False,
#      'deleted_at': None}},
#    'comment': None,
#    'location_in_source': None,
#    'values': [{'id': '78bf7444-b272-69a1-7320-032300ff6f77',
#      'value': 98135070,
#      'unit': {'id': 'c85f4e6e-4752-476e-816a-9525d3bbc129',
#       'name': 'kgCO2e',
#       'unit_type_id': '4de8c2f9-3fe7-421e-8bb3-ea88527b432c',
#       'unit_system_id': '50115948-140f-48fc-b5f2-c56e96869734',
#       'created_at': '2021-11-03T20:45:56.805Z',
#       'updated_at': '2021-11-03T20:45:56.805Z',
#       'deleted_at': None}}],
#    'created_at': '2022-02-11T11:27:05.433Z',
#    'created_by': {'staff_id': 75806,
#     'staff_name': 'Ash Kulkarni',
#     'email': 'Ash.Kulkarni@arup.com',
#     'company_centre_arup_unit': '01-509 Buildings North',
#     'location_name': 'Glasgow Office',
#     'grade_level': 2,
#     'my_people_page_url': 'https://arup-my.sharepoint.com/PersonImmersive.aspx?accountname=i:0%23.f%7cmembership%7cAsh.Kulkarni@arup.com'}},
#   'deleted_at': None},
#  {'id': '6d27e74c-895e-4858-8e0a-c758701dd46f',
#   'created_at': '2022-01-28T10:59:40.357Z',
#   'parameter_type': {'id': '6cbf4335-35f7-4a17-b214-d6c3aaa53685',
#    'name': 'Embodied carbon for stage A4 transport',
#    'data_type': 'number',
#    'unit_type_id': '4de8c2f9-3fe7-421e-8bb3-ea88527b432c',
#    'created_at': '2021-11-03T20:45:56.196Z',
#    'updated_at': '2022-02-03T12:40:18.781Z',
#    'global_parameter': True,
#    'deleted_at': None},
#   'parents': [{'id': 'b4bec7cb-7f52-e2b1-3b38-74a9308d1026',
#     'name': 'Septic tank',
#     'project_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'children': [],
#     'parent': '10bec7cb-77a0-67f3-4887-987442fb68e0',
#     'asset_type': {'id': '49202b68-1ff9-489b-a8ff-9e7d890f1bf4',
#      'parent_id': 'e4b51a06-4f87-4108-9fac-fe44182621fb',
#      'name': 'product',
#      'created_at': '2021-11-03T20:45:55.945Z',
#      'updated_at': '2021-11-03T20:45:55.945Z',
#      'asset_sub_type': False,
#      'deleted_at': None,
#      'asset_type_group': None}}],
#   'revision': {'id': '0ac7607c-d726-47ff-86fa-f9b9a2e957d7',
#    'status': 'answered',
#    'source': {'id': 'e3e5a6f7-4a3f-46e8-8c50-aa06f5c9d11b',
#     'created_at': '2022-02-11T11:09:20.193Z',
#     'updated_at': '2022-02-11T11:09:20.193Z',
#     'deleted_at': None,
#     'time': None,
#     'date_day': None,
#     'date_month': None,
#     'date_year': None,
#     'reference': 'Jupyter',
#     'reference_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'reference_table': 'projects',
#     'reference_url': 'https://ddb.arup.com/project',
#     'scope': None,
#     'title': 'A4 Calc Notebook',
#     'url': None,
#     'source_type': {'id': '3169ba8f-d474-4ee3-8891-09817a03b196',
#      'name': 'Auto',
#      'visible': False,
#      'deleted_at': None}},
#    'comment': None,
#    'location_in_source': None,
#    'values': [{'id': '02bf7444-ade0-acd9-5121-4c52c4e1d9cd',
#      'value': 98135070,
#      'unit': {'id': 'c85f4e6e-4752-476e-816a-9525d3bbc129',
#       'name': 'kgCO2e',
#       'unit_type_id': '4de8c2f9-3fe7-421e-8bb3-ea88527b432c',
#       'unit_system_id': '50115948-140f-48fc-b5f2-c56e96869734',
#       'created_at': '2021-11-03T20:45:56.805Z',
#       'updated_at': '2021-11-03T20:45:56.805Z',
#       'deleted_at': None}}],
#    'created_at': '2022-02-11T11:27:03.095Z',
#    'created_by': {'staff_id': 75806,
#     'staff_name': 'Ash Kulkarni',
#     'email': 'Ash.Kulkarni@arup.com',
#     'company_centre_arup_unit': '01-509 Buildings North',
#     'location_name': 'Glasgow Office',
#     'grade_level': 2,
#     'my_people_page_url': 'https://arup-my.sharepoint.com/PersonImmersive.aspx?accountname=i:0%23.f%7cmembership%7cAsh.Kulkarni@arup.com'}},
#   'deleted_at': None},
#  {'id': 'ca2aeb4c-e01f-4528-90f1-599f20811722',
#   'created_at': '2021-12-06T11:52:58.441Z',
#   'parameter_type': {'id': 'cc9c7e85-60c1-4c3f-a133-cdfd54bc418a',
#    'name': 'Distance travelled by product to site',
#    'data_type': 'number',
#    'unit_type_id': '58b85ce4-b4e5-4993-b302-898159505efc',
#    'created_at': '2021-11-03T20:45:56.196Z',
#    'updated_at': '2022-02-03T12:39:16.172Z',
#    'global_parameter': True,
#    'deleted_at': None},
#   'parents': [{'id': 'b4bec7cb-7f52-e2b1-3b38-74a9308d1026',
#     'name': 'Septic tank',
#     'project_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'children': [],
#     'parent': '10bec7cb-77a0-67f3-4887-987442fb68e0',
#     'asset_type': {'id': '49202b68-1ff9-489b-a8ff-9e7d890f1bf4',
#      'parent_id': 'e4b51a06-4f87-4108-9fac-fe44182621fb',
#      'name': 'product',
#      'created_at': '2021-11-03T20:45:55.945Z',
#      'updated_at': '2021-11-03T20:45:55.945Z',
#      'asset_sub_type': False,
#      'deleted_at': None,
#      'asset_type_group': None}}],
#   'revision': {'id': 'fb49901f-4d74-42a8-b79a-1be7db0a6749',
#    'status': 'answered',
#    'source': {'id': '7e7c80f6-9d35-46fa-9846-17123cd201fb',
#     'created_at': '2022-01-26T15:10:40.875Z',
#     'updated_at': '2022-01-26T15:10:40.875Z',
#     'deleted_at': None,
#     'time': None,
#     'date_day': None,
#     'date_month': None,
#     'date_year': None,
#     'reference': 'Jupyter Notebook',
#     'reference_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'reference_table': 'projects',
#     'reference_url': 'https://ddb.arup.com/project',
#     'scope': None,
#     'title': 'Automation Lab Upload Tool',
#     'url': None,
#     'source_type': {'id': '3169ba8f-d474-4ee3-8891-09817a03b196',
#      'name': 'Auto',
#      'visible': False,
#      'deleted_at': None}},
#    'comment': None,
#    'location_in_source': None,
#    'values': [{'id': '6cbf4b78-69cf-ab46-0ed2-b8a3bc8b2dbc',
#      'value': 125,
#      'unit': {'id': 'd90385c5-6778-4f80-9339-6fbc8ca30441',
#       'name': 'km',
#       'unit_type_id': '58b85ce4-b4e5-4993-b302-898159505efc',
#       'unit_system_id': '50115948-140f-48fc-b5f2-c56e96869734',
#       'created_at': '2021-11-03T20:45:56.805Z',
#       'updated_at': '2021-11-03T20:45:56.805Z',
#       'deleted_at': None}}],
#    'created_at': '2022-01-26T15:11:12.276Z',
#    'created_by': {'staff_id': 75806,
#     'staff_name': 'Ash Kulkarni',
#     'email': 'Ash.Kulkarni@arup.com',
#     'company_centre_arup_unit': '01-509 Buildings North',
#     'location_name': 'Glasgow Office',
#     'grade_level': 2,
#     'my_people_page_url': 'https://arup-my.sharepoint.com/PersonImmersive.aspx?accountname=i:0%23.f%7cmembership%7cAsh.Kulkarni@arup.com'}},
#   'deleted_at': None},
#  {'id': 'fa11d7c0-4eab-4fbf-ad8a-f87aef2d33b5',
#   'created_at': '2021-12-06T11:52:55.202Z',
#   'parameter_type': {'id': 'cc9c7e85-60c1-4c3f-a133-cdfd54bc418a',
#    'name': 'Distance travelled by product to site',
#    'data_type': 'number',
#    'unit_type_id': '58b85ce4-b4e5-4993-b302-898159505efc',
#    'created_at': '2021-11-03T20:45:56.196Z',
#    'updated_at': '2022-02-03T12:39:16.172Z',
#    'global_parameter': True,
#    'deleted_at': None},
#   'parents': [{'id': '72bec7cb-7937-c497-13f4-65f1e7b9b4a4',
#     'name': 'Rainwater collection tank',
#     'project_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'children': [],
#     'parent': '10bec7cb-77a0-67f3-4887-987442fb68e0',
#     'asset_type': {'id': '49202b68-1ff9-489b-a8ff-9e7d890f1bf4',
#      'parent_id': 'e4b51a06-4f87-4108-9fac-fe44182621fb',
#      'name': 'product',
#      'created_at': '2021-11-03T20:45:55.945Z',
#      'updated_at': '2021-11-03T20:45:55.945Z',
#      'asset_sub_type': False,
#      'deleted_at': None,
#      'asset_type_group': None}}],
#   'revision': {'id': '62b9d28f-bbfb-4d61-a687-8cb6df87eb65',
#    'status': 'answered',
#    'source': {'id': '7e7c80f6-9d35-46fa-9846-17123cd201fb',
#     'created_at': '2022-01-26T15:10:40.875Z',
#     'updated_at': '2022-01-26T15:10:40.875Z',
#     'deleted_at': None,
#     'time': None,
#     'date_day': None,
#     'date_month': None,
#     'date_year': None,
#     'reference': 'Jupyter Notebook',
#     'reference_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'reference_table': 'projects',
#     'reference_url': 'https://ddb.arup.com/project',
#     'scope': None,
#     'title': 'Automation Lab Upload Tool',
#     'url': None,
#     'source_type': {'id': '3169ba8f-d474-4ee3-8891-09817a03b196',
#      'name': 'Auto',
#      'visible': False,
#      'deleted_at': None}},
#    'comment': None,
#    'location_in_source': None,
#    'values': [{'id': '6cbf4b78-5323-b5ff-e3ea-aca2d699b8c0',
#      'value': 40,
#      'unit': {'id': 'd90385c5-6778-4f80-9339-6fbc8ca30441',
#       'name': 'km',
#       'unit_type_id': '58b85ce4-b4e5-4993-b302-898159505efc',
#       'unit_system_id': '50115948-140f-48fc-b5f2-c56e96869734',
#       'created_at': '2021-11-03T20:45:56.805Z',
#       'updated_at': '2021-11-03T20:45:56.805Z',
#       'deleted_at': None}}],
#    'created_at': '2022-01-26T15:11:00.652Z',
#    'created_by': {'staff_id': 75806,
#     'staff_name': 'Ash Kulkarni',
#     'email': 'Ash.Kulkarni@arup.com',
#     'company_centre_arup_unit': '01-509 Buildings North',
#     'location_name': 'Glasgow Office',
#     'grade_level': 2,
#     'my_people_page_url': 'https://arup-my.sharepoint.com/PersonImmersive.aspx?accountname=i:0%23.f%7cmembership%7cAsh.Kulkarni@arup.com'}},
#   'deleted_at': None},
#  {'id': 'e3636e98-0af4-4e07-9cd0-4919ff9320d2',
#   'created_at': '2021-12-06T11:52:58.441Z',
#   'parameter_type': {'id': '77f5f67d-93bc-4c54-808e-d5e98a09cf7d',
#    'name': 'Density',
#    'data_type': 'number',
#    'unit_type_id': '395fc8f5-215f-4a5e-a55e-aa26b8ed18fa',
#    'created_at': '2021-11-03T20:45:56.196Z',
#    'updated_at': '2022-02-03T12:37:40.389Z',
#    'global_parameter': True,
#    'deleted_at': None},
#   'parents': [{'id': 'b4bec7cb-7f52-e2b1-3b38-74a9308d1026',
#     'name': 'Septic tank',
#     'project_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'children': [],
#     'parent': '10bec7cb-77a0-67f3-4887-987442fb68e0',
#     'asset_type': {'id': '49202b68-1ff9-489b-a8ff-9e7d890f1bf4',
#      'parent_id': 'e4b51a06-4f87-4108-9fac-fe44182621fb',
#      'name': 'product',
#      'created_at': '2021-11-03T20:45:55.945Z',
#      'updated_at': '2021-11-03T20:45:55.945Z',
#      'asset_sub_type': False,
#      'deleted_at': None,
#      'asset_type_group': None}}],
#   'revision': {'id': '4ad2ed78-3b01-4933-b1c3-45c45d76e6b1',
#    'status': 'answered',
#    'source': {'id': '7e7c80f6-9d35-46fa-9846-17123cd201fb',
#     'created_at': '2022-01-26T15:10:40.875Z',
#     'updated_at': '2022-01-26T15:10:40.875Z',
#     'deleted_at': None,
#     'time': None,
#     'date_day': None,
#     'date_month': None,
#     'date_year': None,
#     'reference': 'Jupyter Notebook',
#     'reference_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'reference_table': 'projects',
#     'reference_url': 'https://ddb.arup.com/project',
#     'scope': None,
#     'title': 'Automation Lab Upload Tool',
#     'url': None,
#     'source_type': {'id': '3169ba8f-d474-4ee3-8891-09817a03b196',
#      'name': 'Auto',
#      'visible': False,
#      'deleted_at': None}},
#    'comment': None,
#    'location_in_source': None,
#    'values': [{'id': '3abf4b78-6f04-5c6b-25be-bb1ccec1d5e0',
#      'value': 240,
#      'unit': {'id': 'e749475e-f19c-4d4f-9d46-360d733c461c',
#       'name': 'kg/m³',
#       'unit_type_id': '395fc8f5-215f-4a5e-a55e-aa26b8ed18fa',
#       'unit_system_id': '50115948-140f-48fc-b5f2-c56e96869734',
#       'created_at': '2021-11-03T20:45:56.805Z',
#       'updated_at': '2021-11-03T20:45:56.805Z',
#       'deleted_at': None}}],
#    'created_at': '2022-01-26T15:11:14.933Z',
#    'created_by': {'staff_id': 75806,
#     'staff_name': 'Ash Kulkarni',
#     'email': 'Ash.Kulkarni@arup.com',
#     'company_centre_arup_unit': '01-509 Buildings North',
#     'location_name': 'Glasgow Office',
#     'grade_level': 2,
#     'my_people_page_url': 'https://arup-my.sharepoint.com/PersonImmersive.aspx?accountname=i:0%23.f%7cmembership%7cAsh.Kulkarni@arup.com'}},
#   'deleted_at': None},
#  {'id': 'bccc0dc2-71bc-4106-8909-78f60293a6a3',
#   'created_at': '2021-12-06T11:52:55.202Z',
#   'parameter_type': {'id': '77f5f67d-93bc-4c54-808e-d5e98a09cf7d',
#    'name': 'Density',
#    'data_type': 'number',
#    'unit_type_id': '395fc8f5-215f-4a5e-a55e-aa26b8ed18fa',
#    'created_at': '2021-11-03T20:45:56.196Z',
#    'updated_at': '2022-02-03T12:37:40.389Z',
#    'global_parameter': True,
#    'deleted_at': None},
#   'parents': [{'id': '72bec7cb-7937-c497-13f4-65f1e7b9b4a4',
#     'name': 'Rainwater collection tank',
#     'project_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'children': [],
#     'parent': '10bec7cb-77a0-67f3-4887-987442fb68e0',
#     'asset_type': {'id': '49202b68-1ff9-489b-a8ff-9e7d890f1bf4',
#      'parent_id': 'e4b51a06-4f87-4108-9fac-fe44182621fb',
#      'name': 'product',
#      'created_at': '2021-11-03T20:45:55.945Z',
#      'updated_at': '2021-11-03T20:45:55.945Z',
#      'asset_sub_type': False,
#      'deleted_at': None,
#      'asset_type_group': None}}],
#   'revision': {'id': 'b4b06fe0-85ce-4883-aa01-419bdbf7053f',
#    'status': 'answered',
#    'source': {'id': 'e3e5a6f7-4a3f-46e8-8c50-aa06f5c9d11b',
#     'created_at': '2022-02-11T11:09:20.193Z',
#     'updated_at': '2022-02-11T11:09:20.193Z',
#     'deleted_at': None,
#     'time': None,
#     'date_day': None,
#     'date_month': None,
#     'date_year': None,
#     'reference': 'Jupyter',
#     'reference_id': '6cfd4db8-aa3c-ec11-8140-005056b57459',
#     'reference_table': 'projects',
#     'reference_url': 'https://ddb.arup.com/project',
#     'scope': None,
#     'title': 'A4 Calc Notebook',
#     'url': None,
#     'source_type': {'id': '3169ba8f-d474-4ee3-8891-09817a03b196',
#      'name': 'Auto',
#      'visible': False,
#      'deleted_at': None}},
#    'comment': None,
#    'location_in_source': None,
#    'values': [{'id': '16bf7bd4-3e16-09de-f3f9-70d8d9f6ffa8',
#      'value': '2400',
#      'unit': {'id': 'e749475e-f19c-4d4f-9d46-360d733c461c',
#       'name': 'kg/m³',
#       'unit_type_id': '395fc8f5-215f-4a5e-a55e-aa26b8ed18fa',
#       'unit_system_id': '50115948-140f-48fc-b5f2-c56e96869734',
#       'created_at': '2021-11-03T20:45:56.805Z',
#       'updated_at': '2021-11-03T20:45:56.805Z',
#       'deleted_at': None}}],
#    'created_at': '2022-02-14T09:55:21.249Z',
#    'created_by': {'staff_id': 75806,
#     'staff_name': 'Ash Kulkarni',
#     'email': 'Ash.Kulkarni@arup.com',
#     'company_centre_arup_unit': '01-509 Buildings North',
#     'location_name': 'Glasgow Office',
#     'grade_level': 2,
#     'my_people_page_url': 'https://arup-my.sharepoint.com/PersonImmersive.aspx?accountname=i:0%23.f%7cmembership%7cAsh.Kulkarni@arup.com'}},
#   'deleted_at': None}]

# %% [markdown]
# Creates a dictionary of every product, their parameters, and asset id.

# %%
product_dict = {}

for x in product_parameters:
    product_dict[x["parents"][0]["name"]] = {} # for every parameter, add the asset it is tied to to the dictionary
    
    # for every parameter, add the parameter type name and value as an entry
for x in product_parameters:
    product_dict[x["parents"][0]["name"]][x["parameter_type"]["name"]] = x["revision"]["values"][0]["value"] 

    # for every parameter, add the asset id
for product in product_parameters:
    product_dict[product["parents"][0]["name"]]["id"] = product["parents"][0]["id"]    

product_dict
# Out:
# {'Septic tank': {'Volume': 10,
#   'Embodied carbon for stage A4 transport': 98135070,
#   'Distance travelled by product to site': 125,
#   'Density': 240,
#   'id': 'b4bec7cb-7f52-e2b1-3b38-74a9308d1026'},
#  'Rainwater collection tank': {'Volume': 11,
#   'Embodied carbon for stage A4 transport': 98135070,
#   'Distance travelled by product to site': 40,
#   'Density': '2400',
#   'id': '72bec7cb-7937-c497-13f4-65f1e7b9b4a4'}}

# %% [markdown]
# ### Get Specific Parameter Quickly

# %% [markdown]
# Gets a particular parameter by instance id (copied from the DDB site)
#
# Creates a similar dictionary.

# %%
parameter_id = "98fc3fed-aea8-4d29-8932-437b4aeaee13"
pyddb.get_parameters(parameter_id = parameter_id)

project_dict = {"Project" : {x["parameter_type"]["name"] : x["revision"]["values"][0]["value"]} for x in pyddb.get_parameters(parameter_id = parameter_id)}
project_dict
# Out:
# {'Project': {'Transport emission carbon factor': '0.25'}}

# %% [markdown]
# ### Post Source

# %% [markdown]
# Posts a new source of the 'auto' type.
#
# Types can be found by using pyddb.get_source_types().

# %%
# creating a new source
project_id
source_type_id = "3169ba8f-d474-4ee3-8891-09817a03b196" # "auto"
source_title = "A4 Calc Notebook"
source_reference = "Jupyter"

# %%
source_id = pyddb.add_new_source(project_id, source_type_id, source_title, source_reference)[0]
source_id
# Out:
# 'e3e5a6f7-4a3f-46e8-8c50-aa06f5c9d11b'

# %% [markdown]
# For each product, try to get 3 parameters: Volume, Density, & Distance travelled to site.
# Perform a simple calculation, then add/update the parameter.
# Parameter type id and unit id found from the DDB data dictionary dashboard.

# %% [markdown]
# ### Perform Calculation & Post Output

# %% [markdown]
# Wrapped in a try/except clause in case the input parameters aren't present on the product.

# %%
for product in product_dict:
    try:
        v = float(product_dict[product]["Volume"])
        d = float(product_dict[product]["Distance travelled by product to site"])
        p = float(product_dict[product]["Density"])

        e = float(project_dict["Project"]["Transport emission carbon factor"])

        a4 = v*d*p*e

        pyddb.add_update_parameter(
            parameter_type_id="6cbf4335-35f7-4a17-b214-d6c3aaa53685",
            project_id = project_id,
            asset_id = product_dict[product]["id"],
            value = a4,
            unit_id = "c85f4e6e-4752-476e-816a-9525d3bbc129",
            source_id = source_id)
        print(f"A4 Carbon up to date for {product}.")
    except KeyError:
        print(f"All parameters not found on {product}.")
# Out:
# A4 Carbon up to date for Septic tank.
# A4 Carbon up to date for Rainwater collection tank.
